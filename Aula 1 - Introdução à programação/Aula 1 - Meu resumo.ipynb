# %% [markdown]
# Comando para instalar uma biblioteca

# %%
# comando para instalar uma biblioteca

# !pip install plyer
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Breve apresentação sobre o curso, professores, instalação de programas e como vai funcionar o projeto final.

# %% [markdown]
# Principais bibliotecas utilizadas durante o curso

# %%
# Principais bibliotecas utilizadas durante o curso

import pandas as pd
import numpy as np
import sqlite3
from datetime import datetime
from plyer import notification
import requests
from tqdm import tqdm

# %% [markdown]
# Primeiro comando

# %%
print("Hello world")
# Out:
# Hello world
