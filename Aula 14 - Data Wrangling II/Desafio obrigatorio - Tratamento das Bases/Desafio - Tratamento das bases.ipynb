# %% [markdown]
# ## Tratamento das Bases
#
# **Descrição**
#
# * Realizar o tratamento das bases coletadas via API do projeto final na aula 12.
#
# **Aspectos a incluir**
#
# * Ajuste os nomes das colunas e linhas.
# * Filtros de linhas e colunas, se necessário.
# * unstack e/ou stack.
# * Tratamento do tipo das variáveis.
# * Ajuste de missing.
# * Tratamento de colunas string.
#
#
# **Observações**
#
# * Você pode criar novas tabelas, salvando as bases brutas e as bases tratadas.
# * As bases finais precisam estar totalmente ajustadas (da melhor forma possível) e salvas no banco de dados.

# %%
#importação de pacotes a serem utilizados
import pandas as pd
import requests
from datetime import datetime

# %%
url = "https://brasilapi.com.br/api/banks/v1"
response = requests.get(url)

# %%
data_banks = response.json()
df_banco = pd.DataFrame(data_banks)

# %%
df_banco
# Out:
#          ispb                        name   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic    NaN
# 3    00038166                       Bacen    NaN
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
# 357                                   NaN    NaN
# 358                                   NaN    NaN
#
#                                               fullName
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
url = "https://brasilapi.com.br/api#tag/TAXAS/ibge/uf/v1"
response_1 = requests.get(url)

# %%
data_ibge = response.json()
df_ibge = pd.DataFrame(data_ibge)

# %%
df_ibge
# Out:
#          ispb                        name   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic    NaN
# 3    00038166                       Bacen    NaN
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
# 357                                   NaN    NaN
# 358                                   NaN    NaN
#
#                                               fullName
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
url = "https://brasilapi.com.br/api/cvm/corretoras/v1"
response2 = requests.get(url)

# %%
data_corretoras = response.json()
df_corretora= pd.DataFrame(data_corretoras)

# %%
df_corretora
# Out:
#          ispb                        name   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic    NaN
# 3    00038166                       Bacen    NaN
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
# 357                                   NaN    NaN
# 358                                   NaN    NaN
#
#                                               fullName
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %% [markdown]
# * 1 - Ajuste os nomes das colunas e linhas.

# %%
df_banco2 = df_banco.rename(columns={'ispb': 'ISPB', 'name' : 'Razao Social', 'code': 'Codigo', 'fullName': 'Nome Completo'})

# %%
df_banco2
# Out:
#          ISPB                Razao Social  Codigo  \
# 0    00000000          BCO DO BRASIL S.A.     1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.    70.0
# 2    00038121                       Selic     NaN
# 3    00038166                       Bacen     NaN
# 4    00122327       SANTINVEST S.A. - CFI   539.0
# ..        ...                         ...     ...
# 354  92875780            WARREN CVMC LTDA   371.0
# 355  92894922              BANCO ORIGINAL   212.0
# 356  94968518                EFX CC LTDA.   289.0
# 357                                   NaN     NaN
# 358                                   NaN     NaN
#
#                                          Nome Completo
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
df_ibge2 = df_ibge.rename(columns={'ispb': 'ISPB', 'name' : 'Razao Social', 'code': 'Codigo', 'fullName': 'Nome Completo'})

# %%
df_ibge2
# Out:
#          ISPB                Razao Social  Codigo  \
# 0    00000000          BCO DO BRASIL S.A.     1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.    70.0
# 2    00038121                       Selic     NaN
# 3    00038166                       Bacen     NaN
# 4    00122327       SANTINVEST S.A. - CFI   539.0
# ..        ...                         ...     ...
# 354  92875780            WARREN CVMC LTDA   371.0
# 355  92894922              BANCO ORIGINAL   212.0
# 356  94968518                EFX CC LTDA.   289.0
# 357                                   NaN     NaN
# 358                                   NaN     NaN
#
#                                          Nome Completo
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %% [markdown]
# * 1.1 - Filtros de linhas e colunas, se necessário.

# %%
filtro = pd.DataFrame(df_ibge2['Codigo'] == 70.0)

# %%
# A saida não saiu exatamente como queria, queria que trouxesse todos os bancos que o cógigo é igual a 70.0
filtro
# Out:
#      Codigo
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# ..      ...
# 354   False
# 355   False
# 356   False
# 357   False
# 358   False
#
# [359 rows x 1 columns]

# %% [markdown]
# * 2 - unstack e/ou stack.

# %%
df_ibge_stack = df_ibge2.groupby('Nome Completo').count()

# %%
df_ibge_stack
# Out:
#                                                     ISPB  Razao Social  Codigo
# Nome Completo
# ACCREDITO - SOCIEDADE DE CRÉDITO DIRETO S.A.           1             1       1
# ACESSO SOLUÇÕES DE PAGAMENTO S.A. - INSTITUIÇÃO...     1             1       1
# ADVANCED CORRETORA DE CÂMBIO LTDA                      1             1       1
# AGK CORRETORA DE CAMBIO S.A.                           1             1       1
# AL5 S.A. CRÉDITO, FINANCIAMENTO E INVESTIMENTO         1             1       1
# ...                                                  ...           ...     ...
# ZEMA CRÉDITO, FINANCIAMENTO E INVESTIMENTO S/A         1             1       1
# ZIPDIN SOLUÇÕES DIGITAIS SOCIEDADE DE CRÉDITO D...     1             1       1
# ÍNDIGO INVESTIMENTOS DISTRIBUIDORA DE TÍTULOS E...     1             1       1
# ÓTIMO SOCIEDADE DE CRÉDITO DIRETO S.A.                 1             1       1
# Órama Distribuidora de Títulos e Valores Mobili...     1             1       1
#
# ...

# %%
df_ibge_stack.stack()
# Out:
# Nome Completo
# ACCREDITO - SOCIEDADE DE CRÉDITO DIRETO S.A.                  ISPB            1
#                                                               Razao Social    1
#                                                               Codigo          1
# ACESSO SOLUÇÕES DE PAGAMENTO S.A. - INSTITUIÇÃO DE PAGAMENTO  ISPB            1
#                                                               Razao Social    1
#                                                                              ..
# ÓTIMO SOCIEDADE DE CRÉDITO DIRETO S.A.                        Razao Social    1
#                                                               Codigo          1
# Órama Distribuidora de Títulos e Valores Mobiliários S.A.     ISPB            1
#                                                               Razao Social    1
#                                                               Codigo          1
# Length: 1065, dtype: int64

# %%
df_ibge_stack.unstack()
# Out:
#         Nome Completo
# ISPB    ACCREDITO - SOCIEDADE DE CRÉDITO DIRETO S.A.                                 1
#         ACESSO SOLUÇÕES DE PAGAMENTO S.A. - INSTITUIÇÃO DE PAGAMENTO                 1
#         ADVANCED CORRETORA DE CÂMBIO LTDA                                            1
#         AGK CORRETORA DE CAMBIO S.A.                                                 1
#         AL5 S.A. CRÉDITO, FINANCIAMENTO E INVESTIMENTO                               1
#                                                                                     ..
# Codigo  ZEMA CRÉDITO, FINANCIAMENTO E INVESTIMENTO S/A                               1
#         ZIPDIN SOLUÇÕES DIGITAIS SOCIEDADE DE CRÉDITO DIRETO S/A                     1
#         ÍNDIGO INVESTIMENTOS DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA.    1
#         ÓTIMO SOCIEDADE DE CRÉDITO DIRETO S.A.                                       1
# ...

# %% [markdown]
# * 3 - Tratamento do tipo das variáveis.

# %%
df_ibge2
# Out:
#          ISPB                Razao Social  Codigo  \
# 0    00000000          BCO DO BRASIL S.A.     1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.    70.0
# 2    00038121                       Selic     NaN
# 3    00038166                       Bacen     NaN
# 4    00122327       SANTINVEST S.A. - CFI   539.0
# ..        ...                         ...     ...
# 354  92875780            WARREN CVMC LTDA   371.0
# 355  92894922              BANCO ORIGINAL   212.0
# 356  94968518                EFX CC LTDA.   289.0
# 357                                   NaN     NaN
# 358                                   NaN     NaN
#
#                                          Nome Completo
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
df_ibge2.dtypes
# Out:
# ISPB              object
# Razao Social      object
# Codigo           float64
# Nome Completo     object
# dtype: object

# %%
df_ibge2['Codigo'] = df_ibge2['Codigo'].astype(int)
df_ibge2
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# c:\Users\regia\OneDrive\Documents\curso\Aula 14 - Data Wrangling II\Desafio obrigatorio - Tratamento das Bases\Desafio - Tratamento das bases.ipynb Célula 25 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/regia/OneDrive/Documents/curso/Aula%2014%20-%20Data%20Wrangling%20II/Desafio%20obrigatorio%20-%20Tratamento%20das%20Bases/Desafio%20-%20Tratamento%20das%20bases.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> df_ibge2['Codigo'] = df_ibge2['Codigo'].astype(int)
#       <a href='vscode-notebook-cell:/c%3A/Users/regia/OneDrive/Documents/curso/Aula%2014%20-%20Data%20Wrangling%20II/Desafio%20obrigatorio%20-%20Tratamento%20das%20Bases/Desafio%20-%20Tratamento%20das%20bases.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> df_ibge2
#
# ...

# %% [markdown]
# * 4 - Ajuste de missing.

# %%
df_ibge3 = df_ibge2[~df_ibge2['Codigo'].isna()]

df_ibge3
# Out:
#          ISPB                Razao Social  Codigo  \
# 0    00000000          BCO DO BRASIL S.A.     1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.    70.0
# 4    00122327       SANTINVEST S.A. - CFI   539.0
# 5    00204963                   CCR SEARA   430.0
# 6    00250699                 AGK CC S.A.   272.0
# ..        ...                         ...     ...
# 352  92856905            ADVANCED CC LTDA   117.0
# 353  92874270           BCO DIGIMAIS S.A.   654.0
# 354  92875780            WARREN CVMC LTDA   371.0
# 355  92894922              BANCO ORIGINAL   212.0
# 356  94968518                EFX CC LTDA.   289.0
#
#                                          Nome Completo
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# 5      COOPERATIVA DE CREDITO RURAL SEARA - CREDISEARA
# 6                         AGK CORRETORA DE CAMBIO S.A.
# ...

# %%
df_ibge3.dtypes
# Out:
# ISPB              object
# Razao Social      object
# Codigo           float64
# Nome Completo     object
# dtype: object

# %%
# Após a correção dos Missing consegui realizar o Astype do DataFrame IBGE 

df_ibge3['Codigo'] = df_ibge3['Codigo'].astype(int)
df_ibge3
# Out:
# C:\Users\regia\AppData\Local\Temp\ipykernel_15496\4137230213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ibge3['Codigo'] = df_ibge3['Codigo'].astype(int)
#          ISPB                Razao Social  Codigo  \
# 0    00000000          BCO DO BRASIL S.A.       1
# 1    00000208  BRB - BCO DE BRASILIA S.A.      70
# 4    00122327       SANTINVEST S.A. - CFI     539
# 5    00204963                   CCR SEARA     430
# 6    00250699                 AGK CC S.A.     272
# ..        ...                         ...     ...
# 352  92856905            ADVANCED CC LTDA     117
# 353  92874270           BCO DIGIMAIS S.A.     654
# 354  92875780            WARREN CVMC LTDA     371
# 355  92894922              BANCO ORIGINAL     212
# ...

# %% [markdown]
# * 5 - Tratamento de colunas string.

# %%
df_ibge3['RAZAO'] = df_ibge3['Razao Social'].str.replace('BCO','BANCO')
# Out:
# C:\Users\regia\AppData\Local\Temp\ipykernel_15496\3466376906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ibge3['RAZAO'] = df_ibge3['Razao Social'].str.replace('BCO','BANCO')

# %%
df_ibge3
# Out:
#          ISPB                Razao Social  Codigo  \
# 0    00000000          BCO DO BRASIL S.A.       1
# 1    00000208  BRB - BCO DE BRASILIA S.A.      70
# 4    00122327       SANTINVEST S.A. - CFI     539
# 5    00204963                   CCR SEARA     430
# 6    00250699                 AGK CC S.A.     272
# ..        ...                         ...     ...
# 352  92856905            ADVANCED CC LTDA     117
# 353  92874270           BCO DIGIMAIS S.A.     654
# 354  92875780            WARREN CVMC LTDA     371
# 355  92894922              BANCO ORIGINAL     212
# 356  94968518                EFX CC LTDA.     289
#
#                                          Nome Completo  \
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# 5      COOPERATIVA DE CREDITO RURAL SEARA - CREDISEARA
# 6                         AGK CORRETORA DE CAMBIO S.A.
# ...
